# %% [markdown]
# <a href="https://colab.research.google.com/github/aayushsharma-15/practice/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/aayushsharma-15/practice
# Out:
# fatal: destination path 'practice' already exists and is not an empty directory.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
cols = ["fLength"	,"fWidth"," fSize","fConc","fConc1","fAsym	","fM3Long","fM3Trans"	,"fAlpha","fDist","class"]
df = pd.read_csv("magic04.data",names=cols)
df.head()
# Out:
#     fLength    fWidth   fSize\t  fConc   fConc1   fAsym\t   fM3Long\t   \
# 0   28.7967   16.0021    2.6449  0.3918   0.1982   27.7004     22.0110
# 1   31.6036   11.7235    2.5185  0.5303   0.3773   26.2722     23.8238
# 2  162.0520  136.0310    4.0612  0.0374   0.0187  116.7410    -64.8580
# 3   23.8172    9.5728    2.3385  0.6147   0.3922   27.2107     -6.4633
# 4   75.1362   30.9205    3.1611  0.3168   0.1832   -5.5277     28.5525
#
#    fM3Trans   fAlpha     fDist class
# 0   -8.2027  40.0920   81.8828     g
# 1   -9.9574   6.3609  205.2610     g
# 2  -45.2160  76.9600  256.7880     g
# 3   -7.1513  10.4490  116.7370     g
# 4   21.8393   4.6480  356.4620     g

# %%
df["class"] = (df["class"]== "g").astype(int)

# %%
df.head()
# Out:
#     fLength    fWidth   fSize\t  fConc   fConc1   fAsym\t   fM3Long\t   \
# 0   28.7967   16.0021    2.6449  0.3918   0.1982   27.7004     22.0110
# 1   31.6036   11.7235    2.5185  0.5303   0.3773   26.2722     23.8238
# 2  162.0520  136.0310    4.0612  0.0374   0.0187  116.7410    -64.8580
# 3   23.8172    9.5728    2.3385  0.6147   0.3922   27.2107     -6.4633
# 4   75.1362   30.9205    3.1611  0.3168   0.1832   -5.5277     28.5525
#
#    fM3Trans   fAlpha     fDist  class
# 0   -8.2027  40.0920   81.8828      1
# 1   -9.9574   6.3609  205.2610      1
# 2  -45.2160  76.9600  256.7880      1
# 3   -7.1513  10.4490  116.7370      1
# 4   21.8393   4.6480  356.4620      1

# %%
for label in cols[:-1]:
  plt.hist( df[df["class"]==1][label],color='blue',label='gamma',alpha=0.7,density = True)
  plt.hist( df[df["class"]==0][label],color='pink',label='hadron',alpha=0.6,density = True)

  plt.title(label)
  plt.ylabel("probability")
  plt.xlabel(label)
  plt.legend()
  plt.show()

# %%
train, valid, test = np.split(df.sample(frac=1), [int(0.6*len(df)),int(0.8*len(df))])

# %%
def scale_dataset(dataframe):
  x= dataframe[dataframe.cols[:-1]].values
  y = dataframe[dataframe.cols[-1]].values

  scaler = StandardScaler()
  x = scaler.fit_transform(x)

  data = np.hstack((x,np.reshape(y,(-1,1))))

  return data, x, y

# %%
train
# Out:
#         fLength   fWidth   fSize\t  fConc   fConc1   fAsym\t   fM3Long\t   \
# 11403   68.0871  22.2841    2.7168  0.2438   0.1353 -100.7860     32.0937
# 671     12.4392  12.0404    2.2000  0.6877   0.3438   15.0011     -0.7681
# 6895    63.6229  40.9327    3.9595  0.1179   0.0636   36.9026     62.4748
# 17354   17.1868  11.1893    2.3284  0.5587   0.3028   -1.6795      6.9433
# 12237   35.0869  32.3780    3.6087  0.1812   0.1045   -6.5013     -8.1597
# ...         ...      ...       ...     ...      ...       ...         ...
# 839     63.5381  26.3231    3.3210  0.1848   0.0938   10.5377     61.2763
# 13812  128.7372  35.0583    2.8948  0.3656   0.2237  137.0544    -61.9409
# 4117    60.2423  17.5709    2.7889  0.2715   0.1585  -48.9314    -48.0945
# 15057   46.3100  21.8396    2.6518  0.4080   0.2776   43.4939     39.9859
# 11087   18.4336   7.4759    2.1287  0.7732   0.4944    1.6194     -5.8546
#
#        fM3Trans   fAlpha     fDist  class
# 11403  -16.7229  24.0960  273.9490      1
# 671     11.2238  18.3994  221.3050      1
# 6895    17.7033   1.0007  144.4440      1
# 17354    4.7963  19.7790  219.7140      0
# 12237   19.1513  76.0740   70.1664      1
# ...         ...      ...       ...    ...
# 839     -4.1837   9.4280  243.3750      1
# 13812   16.8910  38.3465    5.5922      0
# 4117    15.3258  30.2907  187.1060      1
# 15057  -19.9390  56.6947  173.8700      0
# 11087    0.5699  52.8810  125.6090      1
#
# [11412 rows x 11 columns]
